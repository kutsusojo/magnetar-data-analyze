# %%
# relations between R/R_g and S_ν/4πR^2

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.animation as animation
import numpy as np
import math
import scipy.optimize
import os
import matplotlib
from mpl_toolkits.mplot3d import axes3d, Axes3D

r_g_over_R = 1 / 3

def visible_fraction(x):
    y = (2 * (1 - x)) ** (-1)
    return y

x = np.logspace(-100, -1, 10000, base = 2)

fig = plt.figure()
plt.plot(x, visible_fraction(x))
# plt.xscale("log")
plt.xlabel("bending factor: r_g/R")
plt.ylabel("visible fraction: R_nyu/4piR^2")
plt.show()
